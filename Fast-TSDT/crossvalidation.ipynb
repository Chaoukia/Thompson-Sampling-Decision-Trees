# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from tsdt import *
from utils import *
from skmultiflow.trees import HoeffdingTreeClassifier, ExtremelyFastDecisionTreeClassifier
from skmultiflow.data import LEDGenerator
from sklearn.model_selection import KFold
from statistics import median, quantiles
from matplotlib.lines import Line2D
from time import time
import pandas as pd
import seaborn as sns
import pickle as pkl
import os

from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # MONK 1

# %%
data_train = np.genfromtxt('../data/monks-1.train', delimiter=' ', dtype=int)
#np.random.shuffle(data_train)
data_train = data_train[:, :-1] # Getting rid of the last column, it contains only ids.
data_train = data_train[:, ::-1]

data_test = np.genfromtxt('../data/monks-1.test', delimiter=' ', dtype=int)
data_test = data_test[:, :-1] # Getting rid of the last column, it contains only ids.
data_test = data_test[:, ::-1]

labels = set(data_train[:, -1])
K = len(labels)
print('n_train : %d' %data_train.shape[0])
print('n_test : %d' %data_test.shape[0])
# Out:
# n_train : 124
# n_test : 432

# %%
data = np.concatenate((data_train, data_test))
print(data.shape)
# Out:
# (556, 7)

# %%
kf = KFold(shuffle=True, random_state=256)

# %% [markdown]
# ## Drop Last

# %%
encoder = OneHotEncoder(drop=np.array([3, 3, 2, 3, 4, 2][::-1]+[0]), sparse=False)
encoder.fit(data)
data_encoded = encoder.transform(data).astype(int)

# %% [markdown]
# ### Fast-TSDT

# %%
n_iter = 1000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
gamma = 0.75

lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data_encoded)):
        data_train_fold = data_encoded[train_index]
        data_test_fold = data_encoded[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 10.9422
# n_leaves =  2
# train accuracy =  0.7545045045045045
# test accuracy =  0.7142857142857143
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 11.6977
# n_leaves =  2
# train accuracy =  0.7348314606741573
# test accuracy =  0.7927927927927928
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 11.7026
# n_leaves =  2
# train accuracy =  0.7370786516853932
# test accuracy =  0.7837837837837838
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 10.6439
# n_leaves =  2
# train accuracy =  0.7348314606741573
# test accuracy =  0.7927927927927928
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 11.1717
# n_leaves =  2
# train accuracy =  0.7707865168539326
# test accuracy =  0.6486486486486487
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.9693
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 20.2835
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.9176
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.1646
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 20.7275
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.7442
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 19.5637
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.7125
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.7572
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.5709
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.6371
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 21.7868
# n_leaves =  9
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 20.0209
# n_leaves =  9
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 22.8849
# n_leaves =  11
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 20.0679
# n_leaves =  9
# train accuracy =  1.0
# test accuracy =  1.0

# %%
#with open('monk_1/times_last_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(times_egdt, handle)
#    
#with open('monk_1/n_leaves_last_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(n_leaves_egdt, handle)
#    
#with open('monk_1/train_acc_last_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(train_acc_egdt, handle)
#    
#with open('monk_1/test_acc_last_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# ## Drop First

# %%
encoder = OneHotEncoder(drop='first', sparse=False)
encoder.fit(data)
data_encoded = encoder.transform(data).astype(int)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
gamma = 0.75

lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data_encoded)):
        data_train_fold = data_encoded[train_index]
        data_test_fold = data_encoded[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 84.9674
# n_leaves =  1
# train accuracy =  0.5
# test accuracy =  0.5
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 62.4998
# n_leaves =  1
# train accuracy =  0.5078651685393258
# test accuracy =  0.46846846846846846
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 60.1804
# n_leaves =  1
# train accuracy =  0.501123595505618
# test accuracy =  0.4954954954954955
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 58.4387
# n_leaves =  1
# train accuracy =  0.5146067415730337
# test accuracy =  0.44144144144144143
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 54.9547
# n_leaves =  1
# train accuracy =  0.5213483146067416
# test accuracy =  0.4144144144144144
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 247.8480
# n_leaves =  13
# train accuracy =  0.9481981981981982
# test accuracy =  0.9464285714285714
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 255.9902
# n_leaves =  16
# train accuracy =  0.9685393258426966
# test accuracy =  0.990990990990991
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 273.5501
# n_leaves =  13
# train accuracy =  0.952808988764045
# test accuracy =  0.9279279279279279
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 270.8035
# n_leaves =  16
# train accuracy =  0.9797752808988764
# test accuracy =  0.954954954954955
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 248.0203
# n_leaves =  13
# train accuracy =  0.9483146067415731
# test accuracy =  0.954954954954955
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 278.4671
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 298.2393
# n_leaves =  20
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 328.3090
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 315.1172
# n_leaves =  20
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 304.1576
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 315.0944
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 291.0653
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 347.8913
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 322.7846
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 329.0882
# n_leaves =  23
# train accuracy =  0.9910112359550561
# test accuracy =  0.954954954954955

# %%
#with open('monk_1/times_first_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(times_egdt, handle)
#    
#with open('monk_1/n_leaves_first_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(n_leaves_egdt, handle)
#    
#with open('monk_1/train_acc_first_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(train_acc_egdt, handle)
#    
#with open('monk_1/test_acc_first_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# ## Original

# %%
n_iter = 1000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
gamma = 0.75

lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.3557
# n_leaves =  4
# train accuracy =  0.7545045045045045
# test accuracy =  0.7142857142857143
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.3411
# n_leaves =  4
# train accuracy =  0.7348314606741573
# test accuracy =  0.7927927927927928
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.4695
# n_leaves =  4
# train accuracy =  0.7370786516853932
# test accuracy =  0.7837837837837838
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.9665
# n_leaves =  4
# train accuracy =  0.7348314606741573
# test accuracy =  0.7927927927927928
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.7457
# n_leaves =  4
# train accuracy =  0.7707865168539326
# test accuracy =  0.6486486486486487
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.8208
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 15.7944
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.1966
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.4684
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.5097
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.5033
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.3749
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.8675
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.3339
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.0059
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.9733
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.2390
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.2680
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.6013
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.9471
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0

# %%
#with open('monk_1/times_original_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(times_egdt, handle)
#    
#with open('monk_1/n_leaves_original_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(n_leaves_egdt, handle)
#    
#with open('monk_1/train_acc_original_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(train_acc_egdt, handle)
#    
#with open('monk_1/test_acc_original_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # Monk 2

# %%
file = '../data/monk2-train.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (169, 12)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
gamma = 0.75

lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 50.4176
# n_leaves =  1
# train accuracy =  0.6222222222222222
# test accuracy =  0.6176470588235294
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 51.9457
# n_leaves =  1
# train accuracy =  0.6296296296296297
# test accuracy =  0.5882352941176471
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 49.7442
# n_leaves =  1
# train accuracy =  0.6296296296296297
# test accuracy =  0.5882352941176471
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 52.5140
# n_leaves =  1
# train accuracy =  0.6
# test accuracy =  0.7058823529411765
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 50.9751
# n_leaves =  1
# train accuracy =  0.625
# test accuracy =  0.6060606060606061
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 289.6203
# n_leaves =  17
# train accuracy =  0.9037037037037037
# test accuracy =  0.7352941176470589
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 231.7949
# n_leaves =  14
# train accuracy =  0.8814814814814815
# test accuracy =  0.7941176470588235
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 197.6260
# n_leaves =  13
# train accuracy =  0.8666666666666667
# test accuracy =  0.8235294117647058
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 240.5767
# n_leaves =  10
# train accuracy =  0.8296296296296296
# test accuracy =  0.6470588235294118
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 229.1525
# n_leaves =  11
# train accuracy =  0.8455882352941176
# test accuracy =  0.7575757575757576
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 373.1763
# n_leaves =  24
# train accuracy =  0.9481481481481482
# test accuracy =  0.7647058823529411
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 407.4530
# n_leaves =  29
# train accuracy =  0.9925925925925926
# test accuracy =  0.7352941176470589
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 341.3799
# n_leaves =  21
# train accuracy =  0.9111111111111111
# test accuracy =  0.8529411764705882
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 300.6940
# n_leaves =  24
# train accuracy =  0.9481481481481482
# test accuracy =  0.8235294117647058
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 341.9245
# n_leaves =  21
# train accuracy =  0.9191176470588235
# test accuracy =  0.7878787878787878
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 397.6859
# n_leaves =  35
# train accuracy =  1.0
# test accuracy =  0.7058823529411765
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 463.7603
# n_leaves =  35
# train accuracy =  0.9925925925925926
# test accuracy =  0.7352941176470589
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 454.0844
# n_leaves =  36
# train accuracy =  0.9851851851851852
# test accuracy =  0.7352941176470589
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 421.9656
# n_leaves =  37
# train accuracy =  1.0
# test accuracy =  0.9117647058823529
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 417.9018
# n_leaves =  31
# train accuracy =  0.9779411764705882
# test accuracy =  0.8484848484848485

# %%
#with open('monk_2/times_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(times_egdt, handle)
#    
#with open('monk_2/n_leaves_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(n_leaves_egdt, handle)
#    
#with open('monk_2/train_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(train_acc_egdt, handle)
#    
#with open('monk_2/test_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # Monk 3

# %%
file = '../data/monk3-train.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
#np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (122, 12)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
gamma = 0.75

lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 90.2345
# n_leaves =  2
# train accuracy =  0.7216494845360825
# test accuracy =  0.48
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 99.0210
# n_leaves =  2
# train accuracy =  0.6701030927835051
# test accuracy =  0.68
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 118.4713
# n_leaves =  3
# train accuracy =  0.7959183673469388
# test accuracy =  0.7083333333333334
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 118.9738
# n_leaves =  3
# train accuracy =  0.7857142857142857
# test accuracy =  0.75
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 119.6111
# n_leaves =  3
# train accuracy =  0.7959183673469388
# test accuracy =  0.7083333333333334
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 228.3517
# n_leaves =  10
# train accuracy =  0.9484536082474226
# test accuracy =  0.84
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 242.7491
# n_leaves =  12
# train accuracy =  0.9587628865979382
# test accuracy =  0.96
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 198.4170
# n_leaves =  6
# train accuracy =  0.8979591836734694
# test accuracy =  0.7916666666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 235.2803
# n_leaves =  11
# train accuracy =  0.9489795918367347
# test accuracy =  0.9583333333333334
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 238.2536
# n_leaves =  11
# train accuracy =  0.9591836734693877
# test accuracy =  0.875
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 295.0247
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  0.84
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 273.8422
# n_leaves =  18
# train accuracy =  1.0
# test accuracy =  0.96
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 295.1995
# n_leaves =  18
# train accuracy =  1.0
# test accuracy =  0.9166666666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 297.6046
# n_leaves =  20
# train accuracy =  1.0
# test accuracy =  0.9166666666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 269.9845
# n_leaves =  18
# train accuracy =  1.0
# test accuracy =  0.875
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 344.9659
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  0.84
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 418.0601
# n_leaves =  20
# train accuracy =  1.0
# test accuracy =  0.96
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 349.1445
# n_leaves =  24
# train accuracy =  0.9897959183673469
# test accuracy =  0.9166666666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 360.8285
# n_leaves =  23
# train accuracy =  1.0
# test accuracy =  0.7916666666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 274.3391
# n_leaves =  20
# train accuracy =  1.0
# test accuracy =  0.875

# %%
#with open('monk_3/times_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(times_egdt, handle)
#    
#with open('monk_3/n_leaves_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(n_leaves_egdt, handle)
#    
#with open('monk_3/train_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(train_acc_egdt, handle)
#    
#with open('monk_3/test_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # Tic-Tac-Toe

# %%
file = '../data/tic-tac-toe.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (958, 19)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 20000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
gamma = 0.75

lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 111.7722
# n_leaves =  1
# train accuracy =  0.6697127937336814
# test accuracy =  0.5885416666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 110.2398
# n_leaves =  1
# train accuracy =  0.6462140992167101
# test accuracy =  0.6822916666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 111.8908
# n_leaves =  1
# train accuracy =  0.6449086161879896
# test accuracy =  0.6875
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 111.1065
# n_leaves =  1
# train accuracy =  0.6544980443285529
# test accuracy =  0.6492146596858639
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 112.8116
# n_leaves =  1
# train accuracy =  0.651890482398957
# test accuracy =  0.6596858638743456
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 391.9422
# n_leaves =  6
# train accuracy =  0.7754569190600522
# test accuracy =  0.7447916666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 404.1459
# n_leaves =  8
# train accuracy =  0.8276762402088773
# test accuracy =  0.8333333333333334
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 411.3318
# n_leaves =  8
# train accuracy =  0.804177545691906
# test accuracy =  0.796875
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 408.9262
# n_leaves =  7
# train accuracy =  0.7614080834419817
# test accuracy =  0.7591623036649214
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 422.0004
# n_leaves =  6
# train accuracy =  0.8044328552803129
# test accuracy =  0.7905759162303665
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 488.2097
# n_leaves =  13
# train accuracy =  0.8707571801566579
# test accuracy =  0.828125
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# execution time : 600.0173
# n_leaves =  17
# train accuracy =  0.8785900783289817
# test accuracy =  0.890625
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 553.8983
# n_leaves =  17
# train accuracy =  0.8981723237597912
# test accuracy =  0.8385416666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# ...
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# execution time : 600.0487
# n_leaves =  21
# train accuracy =  0.9073107049608355
# test accuracy =  0.8697916666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# execution time : 600.0246
# n_leaves =  20
# train accuracy =  0.8968668407310705
# test accuracy =  0.890625
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 563.4290
# n_leaves =  19
# train accuracy =  0.8929503916449086
# test accuracy =  0.84375
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# execution time : 600.0622
# n_leaves =  18
# train accuracy =  0.8930899608865711
# test accuracy =  0.8115183246073299
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 588.5251
# n_leaves =  18
# train accuracy =  0.8891786179921773
# test accuracy =  0.8534031413612565

# %%
#with open('tic-tac-toe/times_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(times_egdt, handle)
#    
#with open('tic-tac-toe/n_leaves_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(n_leaves_egdt, handle)
#    
#with open('tic-tac-toe/train_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(train_acc_egdt, handle)
#    
#with open('tic-tac-toe/test_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # Car Evaluation

# %%
file = '../data/car-evaluation.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (1728, 16)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
gamma = 1

lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 53.7707
# n_leaves =  1
# train accuracy =  0.7018813314037626
# test accuracy =  0.6936416184971098
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 55.8294
# n_leaves =  1
# train accuracy =  0.7047756874095513
# test accuracy =  0.6820809248554913
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 52.7905
# n_leaves =  1
# train accuracy =  0.691027496382055
# test accuracy =  0.7369942196531792
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 52.6414
# n_leaves =  1
# train accuracy =  0.7035430224150397
# test accuracy =  0.6869565217391305
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 55.0009
# n_leaves =  1
# train accuracy =  0.6999276934201012
# test accuracy =  0.7014492753623188
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 222.5623
# n_leaves =  7
# train accuracy =  0.9283646888567294
# test accuracy =  0.9104046242774566
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 211.4407
# n_leaves =  7
# train accuracy =  0.9261939218523878
# test accuracy =  0.9190751445086706
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 212.6336
# n_leaves =  7
# train accuracy =  0.9276410998552822
# test accuracy =  0.9132947976878613
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 214.4356
# n_leaves =  7
# train accuracy =  0.918293564714389
# test accuracy =  0.9507246376811594
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 214.8570
# n_leaves =  7
# train accuracy =  0.923355025307303
# test accuracy =  0.9304347826086956
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 247.2926
# n_leaves =  11
# train accuracy =  0.9486251808972503
# test accuracy =  0.9335260115606936
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 243.9974
# n_leaves =  9
# train accuracy =  0.9406657018813314
# test accuracy =  0.930635838150289
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 287.2948
# n_leaves =  11
# train accuracy =  0.9435600578871202
# test accuracy =  0.9190751445086706
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 273.1320
# n_leaves =  11
# train accuracy =  0.9399855386840202
# test accuracy =  0.9681159420289855
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 278.2770
# n_leaves =  11
# train accuracy =  0.9450469992769343
# test accuracy =  0.9478260869565217
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# execution time : 600.0937
# n_leaves =  39
# train accuracy =  0.9782923299565847
# test accuracy =  0.9479768786127167
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# execution time : 600.0657
# n_leaves =  38
# train accuracy =  0.9775687409551375
# test accuracy =  0.9682080924855492
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# execution time : 600.0571
# n_leaves =  31
# train accuracy =  0.975397973950796
# test accuracy =  0.9595375722543352
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 600.0594
# n_leaves =  23
# train accuracy =  0.9587852494577006
# test accuracy =  0.9681159420289855
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# execution time : 600.0391
# n_leaves =  36
# train accuracy =  0.9775849602313811
# test accuracy =  0.9739130434782609

# %%
#with open('car-evaluation/times_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(times_egdt, handle)
#    
#with open('car-evaluation/n_leaves_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(n_leaves_egdt, handle)
#    
#with open('car-evaluation/train_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(train_acc_egdt, handle)
#    
#with open('car-evaluation/test_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # COMPAS

# %%
file = '../data/compas-binary.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (6907, 13)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
gamma = 1

lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 55.9813
# n_leaves =  1
# train accuracy =  0.5444343891402715
# test accuracy =  0.5086830680173662
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 88.6389
# n_leaves =  2
# train accuracy =  0.6419909502262443
# test accuracy =  0.6266280752532561
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 64.0135
# n_leaves =  1
# train accuracy =  0.5407166123778502
# test accuracy =  0.5235336712527154
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 90.8289
# n_leaves =  2
# train accuracy =  0.6395222584147665
# test accuracy =  0.6364952932657495
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 57.7639
# n_leaves =  1
# train accuracy =  0.5325732899022801
# test accuracy =  0.556118754525706
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 207.4542
# n_leaves =  7
# train accuracy =  0.6515837104072398
# test accuracy =  0.6447178002894356
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 206.4750
# n_leaves =  6
# train accuracy =  0.6595475113122172
# test accuracy =  0.6360347322720694
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 209.9178
# n_leaves =  7
# train accuracy =  0.6615997104596453
# test accuracy =  0.6517016654598118
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 210.1865
# n_leaves =  7
# train accuracy =  0.6567137169743033
# test accuracy =  0.6488052136133237
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 211.4774
# n_leaves =  7
# train accuracy =  0.6599710459645313
# test accuracy =  0.6828385228095583
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 217.8900
# n_leaves =  7
# train accuracy =  0.6620814479638009
# test accuracy =  0.6635311143270622
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 221.9471
# n_leaves =  8
# train accuracy =  0.6635294117647059
# test accuracy =  0.6454413892908828
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 224.8491
# n_leaves =  7
# train accuracy =  0.6558089033659066
# test accuracy =  0.6524257784214338
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 228.1032
# n_leaves =  7
# train accuracy =  0.6619616359030039
# test accuracy =  0.6459087617668356
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 227.0158
# n_leaves =  8
# train accuracy =  0.6518277234889612
# test accuracy =  0.6698044895003621
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 229.1336
# n_leaves =  9
# train accuracy =  0.6604524886877828
# test accuracy =  0.6548480463096961
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 244.9954
# n_leaves =  7
# train accuracy =  0.6530316742081448
# test accuracy =  0.6396526772793053
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 228.5457
# n_leaves =  7
# train accuracy =  0.6568946796959826
# test accuracy =  0.6538740043446778
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 236.5104
# n_leaves =  9
# train accuracy =  0.6710097719869706
# test accuracy =  0.6574945691527878
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 232.4059
# n_leaves =  9
# train accuracy =  0.6606948968512486
# test accuracy =  0.6835626357711803

# %%
#with open('compas/times_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(times_egdt, handle)
#    
#with open('compas/n_leaves_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(n_leaves_egdt, handle)
#    
#with open('compas/train_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(train_acc_egdt, handle)
#    
#with open('compas/test_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # FICO

# %%
file = '../data/fico_binary.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (10459, 18)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
gamma = 1

lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 111.2972
# n_leaves =  2
# train accuracy =  0.6943946456316481
# test accuracy =  0.6935946462715105
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 108.2754
# n_leaves =  2
# train accuracy =  0.6979801601529819
# test accuracy =  0.6878585086042065
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 108.0130
# n_leaves =  2
# train accuracy =  0.6963069200430262
# test accuracy =  0.6945506692160612
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 108.1313
# n_leaves =  2
# train accuracy =  0.697143540098004
# test accuracy =  0.6912045889101338
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 108.1541
# n_leaves =  2
# train accuracy =  0.6939531548757171
# test accuracy =  0.7039693926351028
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 233.0653
# n_leaves =  7
# train accuracy =  0.694275128480937
# test accuracy =  0.6940726577437859
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 229.2012
# n_leaves =  5
# train accuracy =  0.6955898171387594
# test accuracy =  0.6888145315487572
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 234.5646
# n_leaves =  7
# train accuracy =  0.6967849886458707
# test accuracy =  0.6897705544933078
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 228.9807
# n_leaves =  7
# train accuracy =  0.7002509860164934
# test accuracy =  0.7017208413001912
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 234.1678
# n_leaves =  7
# train accuracy =  0.6987332695984704
# test accuracy =  0.7097082735533238
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 243.9912
# n_leaves =  7
# train accuracy =  0.6990558145093821
# test accuracy =  0.6988527724665392
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 241.7381
# n_leaves =  7
# train accuracy =  0.7108880124297837
# test accuracy =  0.6926386233269598
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 244.1222
# n_leaves =  8
# train accuracy =  0.698936297358671
# test accuracy =  0.6888145315487572
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 255.1709
# n_leaves =  7
# train accuracy =  0.698099677303693
# test accuracy =  0.7002868068833652
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 275.5018
# n_leaves =  7
# train accuracy =  0.6995697896749522
# test accuracy =  0.7054041128646581
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 281.7823
# n_leaves =  7
# train accuracy =  0.6943946456316481
# test accuracy =  0.6935946462715105
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 268.3912
# n_leaves =  8
# train accuracy =  0.7077805665112944
# test accuracy =  0.6998087954110899
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 271.4316
# n_leaves =  7
# train accuracy =  0.7061073264013386
# test accuracy =  0.7103250478011472
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 268.2988
# n_leaves =  7
# train accuracy =  0.6959483685908928
# test accuracy =  0.7017208413001912
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 261.8606
# n_leaves =  8
# train accuracy =  0.7068594646271511
# test accuracy =  0.7183165949306551

# %%
#with open('fico/times_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(times_egdt, handle)
#    
#with open('fico/n_leaves_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(n_leaves_egdt, handle)
#    
#with open('fico/train_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(train_acc_egdt, handle)
#    
#with open('fico/test_acc_fasttsdt.pickle', 'wb') as handle:
#    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # Summary

# %%
#algs = ['dl85', 'osdt', 'fasttsdt', 'tsdt']
algs = ['fasttsdt']
res = ['n_leaves', 'train_acc', 'test_acc', 'times']

# %%
def construct(prob, data):
#    d = {'dl85' : {}, 'osdt' : {}, 'fasttsdt' : {}, 'tsdt' : {}}
    d = {'fasttsdt' : {}}

    for result in res:
#        d['dl85'][result] = {}
#        for depth in depths:
#            d['dl85'][result][depth] = quantiles(data[result + prob + 'dl85'][depth])

#        d['osdt'][result] = {}
        d['fasttsdt'][result] = {}
#        d['tsdt'][result] = {}
        for lamb in lambs:
#            d['osdt'][result][lamb] = quantiles(data[result + prob + 'osdt'][lamb])
            d['fasttsdt'][result][lamb] = quantiles(data[result + prob + 'fasttsdt'][lamb])
#            d['tsdt'][result][lamb] = quantiles(data[result + prob + 'tsdt'][lamb])
            
    return d

# %%
#legend_elements = [Line2D([0], [0], marker='o', color='b', label='dl85', markerfacecolor='b'), 
#                   Line2D([0], [0], marker='s', color='g', label='osdt', markerfacecolor='g'), 
#                   Line2D([0], [0], marker='v', color='r', label='fast-tsdt', markerfacecolor='r'), 
#                   Line2D([0], [0], marker='^', color='y', label='tsdt', markerfacecolor='y')]

legend_elements = [Line2D([0], [0], marker='v', color='r', label='fast-tsdt', markerfacecolor='r')]

def plot_restuls(d, result, depths, lambs, ax):
#    for i, depth in enumerate(depths):
#        ax.plot(d['dl85']['n_leaves'][depth][1], d['dl85'][result][depth][1], marker='o', color='b')
#        ax.plot([d['dl85']['n_leaves'][depth][1], d['dl85']['n_leaves'][depth][1]], 
#                [d['dl85'][result][depth][0], d['dl85'][result][depth][2]], color='b')
#        ax.plot([d['dl85']['n_leaves'][depth][0], d['dl85']['n_leaves'][depth][2]], 
#                [d['dl85'][result][depth][1], d['dl85'][result][depth][1]], color='b')

    for i, lamb in enumerate(lambs):
#        ax.plot(d['osdt']['n_leaves'][lamb][1], d['osdt'][result][lamb][1], marker='s', color='g')
#        ax.plot([d['osdt']['n_leaves'][lamb][1], d['osdt']['n_leaves'][lamb][1]], 
#                [d['osdt'][result][lamb][0], d['osdt'][result][lamb][2]], color='g')
#        ax.plot([d['osdt']['n_leaves'][lamb][0], d['osdt']['n_leaves'][lamb][2]], 
#                [d['osdt'][result][lamb][1], d['osdt'][result][lamb][1]], color='g')


        ax.plot(d['fasttsdt']['n_leaves'][lamb][1], d['fasttsdt'][result][lamb][1], marker='v', color='r')
        ax.plot([d['fasttsdt']['n_leaves'][lamb][1], d['fasttsdt']['n_leaves'][lamb][1]], 
                [d['fasttsdt'][result][lamb][0], d['fasttsdt'][result][lamb][2]], color='r')
        ax.plot([d['fasttsdt']['n_leaves'][lamb][0], d['fasttsdt']['n_leaves'][lamb][2]], 
                [d['fasttsdt'][result][lamb][1], d['fasttsdt'][result][lamb][1]], color='r')
        
        
#        ax.plot(d['tsdt']['n_leaves'][lamb][1], d['tsdt'][result][lamb][1], marker='^', color='y')
#        ax.plot([d['tsdt']['n_leaves'][lamb][1], d['tsdt']['n_leaves'][lamb][1]], 
#                [d['tsdt'][result][lamb][0], d['tsdt'][result][lamb][2]], color='y')
#        ax.plot([d['tsdt']['n_leaves'][lamb][0], d['tsdt']['n_leaves'][lamb][2]], 
#                [d['tsdt'][result][lamb][1], d['tsdt'][result][lamb][1]], color='y')

# %% [markdown]
# ## Loading the results for Monk 1

# %%
monk_1 = {}
directory = 'monk_1/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    monk_1[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %% [markdown]
# ### Original

# %%
prob = '_original_'
#monk_1_original_quartiles = {'fasttsdt' : {}, 'tsdt' : {}}
monk_1_original_quartiles = {'fasttsdt' : {}}
for result in res:
    monk_1_original_quartiles['fasttsdt'][result] = {}
#    monk_1_original_quartiles['tsdt'][result] = {}
    for lamb in lambs:
        monk_1_original_quartiles['fasttsdt'][result][lamb] = quantiles(monk_1[result + prob + 'fasttsdt'][lamb])
#        monk_1_original_quartiles['tsdt'][result][lamb] = quantiles(monk_1[result + prob + 'tsdt'][lamb])

# %%
result = 'test_acc'
for i, lamb in enumerate(lambs):
    plt.plot(monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt'][result][lamb][1], marker='v', color='r')
    plt.plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['fasttsdt'][result][lamb][0], monk_1_original_quartiles['fasttsdt'][result][lamb][2]], color='r')
    plt.plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['fasttsdt'][result][lamb][1], monk_1_original_quartiles['fasttsdt'][result][lamb][1]], color='r')
    
#    plt.plot(monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt'][result][lamb][1], marker='^', color='y')
#    plt.plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1]], 
#            [monk_1_original_quartiles['tsdt'][result][lamb][0], monk_1_original_quartiles['tsdt'][result][lamb][2]], color='y')
#    plt.plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][2]], 
#            [monk_1_original_quartiles['tsdt'][result][lamb][1], monk_1_original_quartiles['tsdt'][result][lamb][1]], color='y')
        
plt.show()

# %% [markdown]
# ### Drop Last

# %%
prob = '_last_'
monk_1_last_quartiles = construct(prob, monk_1)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(monk_1_last_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(monk_1_last_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(monk_1_last_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Drop First

# %%
prob = '_first_'
monk_1_first_quartiles = construct(prob, monk_1)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(monk_1_first_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(monk_1_first_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(monk_1_first_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for Monk 2

# %%
monk_2 = {}
directory = 'monk_2/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    monk_2[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
monk_2_quartiles = construct(prob, monk_2)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(monk_2_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(monk_2_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(monk_2_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for Monk 3

# %%
monk_3 = {}
directory = 'monk_3/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    monk_3[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
monk_3_quartiles = construct(prob, monk_3)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(monk_3_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(monk_3_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(monk_3_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for Tic-Tac-Toe

# %%
tic_tac_toe = {}
directory = 'tic-tac-toe/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    tic_tac_toe[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
tic_tac_toe_quartiles = construct(prob, tic_tac_toe)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(tic_tac_toe_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(tic_tac_toe_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(tic_tac_toe_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for Car-Evaluation

# %%
car = {}
directory = 'car-evaluation/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    car[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
car_quartiles = construct(prob, car)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(car_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(car_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(car_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for COMPAS

# %%
compas = {}
directory = 'compas/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    compas[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
compas_quartiles = construct(prob, compas)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(compas_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(compas_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(compas_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for FICO

# %%
fico = {}
directory = 'fico/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    fico[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
fico_quartiles = construct(prob, fico)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(fico_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(fico_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(fico_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Concluding Figures

# %%
fig, axs = plt.subplots(3, 3, figsize=(26, 16))

prob = 'train_acc'

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_1_last_quartiles, prob, depths, lambs, axs[0, 0])
axs[0, 0].set_title('MONK1 Drop last', fontsize=30)
axs[0, 0].set_ylabel('Training Accuracy', fontsize=24)
axs[0, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_1_first_quartiles, prob, depths, lambs, axs[0, 1])
axs[0, 1].set_title('MONK1 Drop first', fontsize=30)
axs[0, 1].tick_params(axis='both', labelsize=20)

for i, lamb in enumerate(lambs):
    axs[0, 2].plot(monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1], marker='v', color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][0], monk_1_original_quartiles['fasttsdt'][prob][lamb][2]], color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1]], color='r')
    
#    axs[0, 2].plot(monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1], marker='^', color='y')
#    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1]], 
#            [monk_1_original_quartiles['tsdt'][prob][lamb][0], monk_1_original_quartiles['tsdt'][prob][lamb][2]], color='y')
#    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][2]], 
#            [monk_1_original_quartiles['tsdt'][prob][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1]], color='y')
    
axs[0, 2].set_title('MONK1 Original', fontsize=30)
axs[0, 2].tick_params(axis='both', labelsize=20)

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_2_quartiles, prob, depths, lambs, axs[1, 0])
axs[1, 0].set_title('MONK2', fontsize=30)
axs[1, 0].set_ylabel('Training Accuracy', fontsize=24)
axs[1, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_3_quartiles, prob, depths, lambs, axs[1, 1])
axs[1, 1].set_title('MONK3', fontsize=30)
axs[1, 1].tick_params(axis='both', labelsize=20)

plot_restuls(tic_tac_toe_quartiles, prob, depths, lambs, axs[1, 2])
axs[1, 2].set_title('Tic-Tac-Toe', fontsize=30)
axs[1, 2].tick_params(axis='both', labelsize=20)

plot_restuls(car_quartiles, prob, depths, lambs, axs[2, 0])
axs[2, 0].set_title('Car-Evaluation', fontsize=30)
axs[2, 0].set_ylabel('Training Accuracy', fontsize=24)
axs[2, 0].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 0].tick_params(axis='both', labelsize=20)

plot_restuls(compas_quartiles, prob, depths, lambs, axs[2, 1])
axs[2, 1].set_title('COMPAS', fontsize=30)
axs[2, 1].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 1].tick_params(axis='both', labelsize=20)

plot_restuls(fico_quartiles, prob, depths, lambs, axs[2, 2])
axs[2, 2].set_title('FICO', fontsize=30)
axs[2, 2].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 2].tick_params(axis='both', labelsize=20)

plt.legend(handles=legend_elements, loc='lower right', fontsize=20)
plt.tight_layout()
#plt.savefig('train_accuracies.pdf')
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(26, 16))

prob = 'test_acc'

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_1_last_quartiles, prob, depths, lambs, axs[0, 0])
axs[0, 0].set_title('MONK1 Drop last', fontsize=30)
axs[0, 0].set_ylabel('Test Accuracy', fontsize=24)
axs[0, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_1_first_quartiles, prob, depths, lambs, axs[0, 1])
axs[0, 1].set_title('MONK1 Drop first', fontsize=30)
axs[0, 1].tick_params(axis='both', labelsize=20)

for i, lamb in enumerate(lambs):
    axs[0, 2].plot(monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1], marker='v', color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][0], monk_1_original_quartiles['fasttsdt'][prob][lamb][2]], color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1]], color='r')
    
#    axs[0, 2].plot(monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1], marker='^', color='y')
#    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1]], 
#            [monk_1_original_quartiles['tsdt'][prob][lamb][0], monk_1_original_quartiles['tsdt'][prob][lamb][2]], color='y')
#    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][2]], 
#            [monk_1_original_quartiles['tsdt'][prob][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1]], color='y')
    
axs[0, 2].set_title('MONK1 Original', fontsize=30)
axs[0, 2].tick_params(axis='both', labelsize=20)

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_2_quartiles, prob, depths, lambs, axs[1, 0])
axs[1, 0].set_title('MONK2', fontsize=30)
axs[1, 0].set_ylabel('Test Accuracy', fontsize=24)
axs[1, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_3_quartiles, prob, depths, lambs, axs[1, 1])
axs[1, 1].set_title('MONK3', fontsize=30)
axs[1, 1].tick_params(axis='both', labelsize=20)

plot_restuls(tic_tac_toe_quartiles, prob, depths, lambs, axs[1, 2])
axs[1, 2].set_title('Tic-Tac-Toe', fontsize=30)
axs[1, 2].tick_params(axis='both', labelsize=20)

plot_restuls(car_quartiles, prob, depths, lambs, axs[2, 0])
axs[2, 0].set_title('Car-Evaluation', fontsize=30)
axs[2, 0].set_ylabel('Test Accuracy', fontsize=24)
axs[2, 0].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 0].tick_params(axis='both', labelsize=20)

plot_restuls(compas_quartiles, prob, depths, lambs, axs[2, 1])
axs[2, 1].set_title('COMPAS', fontsize=30)
axs[2, 1].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 1].tick_params(axis='both', labelsize=20)

plot_restuls(fico_quartiles, prob, depths, lambs, axs[2, 2])
axs[2, 2].set_title('FICO', fontsize=30)
axs[2, 2].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 2].tick_params(axis='both', labelsize=20)

plt.legend(handles=legend_elements, loc='lower right', fontsize=20)
plt.tight_layout()
#plt.savefig('test_accuracies.pdf')
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(26, 16))

prob = 'times'

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_1_last_quartiles, prob, depths, lambs, axs[0, 0])
axs[0, 0].set_title('MONK1 Drop last', fontsize=30)
axs[0, 0].set_ylabel('Time (s)', fontsize=24)
axs[0, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_1_first_quartiles, prob, depths, lambs, axs[0, 1])
axs[0, 1].set_title('MONK1 Drop first', fontsize=30)
axs[0, 1].tick_params(axis='both', labelsize=20)

for i, lamb in enumerate(lambs):
    axs[0, 2].plot(monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1], marker='v', color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][0], monk_1_original_quartiles['fasttsdt'][prob][lamb][2]], color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1]], color='r')
    
#    axs[0, 2].plot(monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1], marker='^', color='y')
#    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1]], 
#            [monk_1_original_quartiles['tsdt'][prob][lamb][0], monk_1_original_quartiles['tsdt'][prob][lamb][2]], color='y')
#    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][2]], 
#            [monk_1_original_quartiles['tsdt'][prob][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1]], color='y')
    
axs[0, 2].set_title('MONK1 Original', fontsize=30)
axs[0, 2].tick_params(axis='both', labelsize=20)

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_2_quartiles, prob, depths, lambs, axs[1, 0])
axs[1, 0].set_title('MONK2', fontsize=30)
axs[1, 0].set_ylabel('Time (s)', fontsize=24)
axs[1, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_3_quartiles, prob, depths, lambs, axs[1, 1])
axs[1, 1].set_title('MONK3', fontsize=30)
axs[1, 1].tick_params(axis='both', labelsize=20)

plot_restuls(tic_tac_toe_quartiles, prob, depths, lambs, axs[1, 2])
axs[1, 2].set_title('Tic-Tac-Toe', fontsize=30)
axs[1, 2].tick_params(axis='both', labelsize=20)

plot_restuls(car_quartiles, prob, depths, lambs, axs[2, 0])
axs[2, 0].set_title('Car-Evaluation', fontsize=30)
axs[2, 0].set_ylabel('Time (s)', fontsize=24)
axs[2, 0].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 0].tick_params(axis='both', labelsize=20)

plot_restuls(compas_quartiles, prob, depths, lambs, axs[2, 1])
axs[2, 1].set_title('COMPAS', fontsize=30)
axs[2, 1].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 1].tick_params(axis='both', labelsize=20)

plot_restuls(fico_quartiles, prob, depths, lambs, axs[2, 2])
axs[2, 2].set_title('FICO', fontsize=30)
axs[2, 2].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 2].tick_params(axis='both', labelsize=20)

plt.legend(handles=legend_elements, loc='lower right', fontsize=20)
plt.tight_layout()
#plt.savefig('times.pdf')
plt.show()
