# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from tsdt import *
from utils import *
from skmultiflow.trees import HoeffdingTreeClassifier, ExtremelyFastDecisionTreeClassifier
from skmultiflow.data import LEDGenerator
from sklearn.model_selection import KFold
from statistics import median, quantiles
from matplotlib.lines import Line2D
from time import time
import pandas as pd
import seaborn as sns
import pickle as pkl
import os

from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # MONK 1

# %%
data_train = np.genfromtxt('../data/monks-1.train', delimiter=' ', dtype=int)
#np.random.shuffle(data_train)
data_train = data_train[:, :-1] # Getting rid of the last column, it contains only ids.
data_train = data_train[:, ::-1]

data_test = np.genfromtxt('../data/monks-1.test', delimiter=' ', dtype=int)
data_test = data_test[:, :-1] # Getting rid of the last column, it contains only ids.
data_test = data_test[:, ::-1]

labels = set(data_train[:, -1])
K = len(labels)
print('n_train : %d' %data_train.shape[0])
print('n_test : %d' %data_test.shape[0])
# Out:
# n_train : 124
# n_test : 432

# %%
data = np.concatenate((data_train, data_test))
print(data.shape)
# Out:
# (556, 7)

# %%
kf = KFold(shuffle=True, random_state=256)

# %% [markdown]
# ## Drop Last

# %%
encoder = OneHotEncoder(drop=np.array([3, 3, 2, 3, 4, 2][::-1]+[0]), sparse=False)
encoder.fit(data)
data_encoded = encoder.transform(data).astype(int)

# %% [markdown]
# ### Fast-TSDT

# %%
n_iter = 1000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
gamma = 0.75

#lambs = [0.2, 0.1, 0.05, 0.025, 0.01, 0.005, 0.0025, 0.001, 0.0005, 0.00025, 0.0001]
lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data_encoded)):
        data_train_fold = data_encoded[train_index]
        data_test_fold = data_encoded[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 9.2414
# n_leaves =  2
# train accuracy =  0.7545045045045045
# test accuracy =  0.7142857142857143
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 9.5568
# n_leaves =  2
# train accuracy =  0.7348314606741573
# test accuracy =  0.7927927927927928
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 9.2984
# n_leaves =  2
# train accuracy =  0.7370786516853932
# test accuracy =  0.7837837837837838
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 9.1879
# n_leaves =  2
# train accuracy =  0.7348314606741573
# test accuracy =  0.7927927927927928
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.7663
# n_leaves =  2
# train accuracy =  0.7707865168539326
# test accuracy =  0.6486486486486487
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.3104
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 15.8910
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.3086
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.5173
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.8540
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.9388
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.4733
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.3797
# n_leaves =  9
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.2160
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.5903
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 18.4544
# n_leaves =  12
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.7143
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.1067
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.5726
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.6617
# n_leaves =  8
# train accuracy =  1.0
# test accuracy =  1.0

# %%
with open('monk_1/times_last_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(times_egdt, handle)
    
with open('monk_1/n_leaves_last_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(n_leaves_egdt, handle)
    
with open('monk_1/train_acc_last_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(train_acc_egdt, handle)
    
with open('monk_1/test_acc_last_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# ## Drop First

# %%
encoder = OneHotEncoder(drop='first', sparse=False)
encoder.fit(data)
data_encoded = encoder.transform(data).astype(int)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
#lambd = 0.0025
gamma = 0.75

#lambs = [0.2, 0.1, 0.05, 0.025, 0.01, 0.005, 0.0025, 0.001, 0.0005, 0.00025, 0.0001]
lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data_encoded)):
        data_train_fold = data_encoded[train_index]
        data_test_fold = data_encoded[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 79.0476
# n_leaves =  1
# train accuracy =  0.5
# test accuracy =  0.5
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 60.2030
# n_leaves =  1
# train accuracy =  0.5078651685393258
# test accuracy =  0.46846846846846846
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 59.0431
# n_leaves =  1
# train accuracy =  0.501123595505618
# test accuracy =  0.4954954954954955
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 56.0283
# n_leaves =  1
# train accuracy =  0.5146067415730337
# test accuracy =  0.44144144144144143
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 54.6370
# n_leaves =  1
# train accuracy =  0.5213483146067416
# test accuracy =  0.4144144144144144
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 212.0608
# n_leaves =  16
# train accuracy =  0.972972972972973
# test accuracy =  0.9732142857142857
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 225.8273
# n_leaves =  13
# train accuracy =  0.9550561797752809
# test accuracy =  0.9279279279279279
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 249.2952
# n_leaves =  13
# train accuracy =  0.952808988764045
# test accuracy =  0.9099099099099099
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 245.5054
# n_leaves =  16
# train accuracy =  0.9797752808988764
# test accuracy =  0.954954954954955
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 198.7308
# n_leaves =  9
# train accuracy =  0.8382022471910112
# test accuracy =  0.8108108108108109
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 292.7576
# n_leaves =  20
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 319.3507
# n_leaves =  23
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 285.6205
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 233.9267
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 247.2171
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 278.2968
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 281.7928
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 294.5894
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 308.2080
# n_leaves =  20
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 294.0482
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  1.0

# %%
with open('monk_1/times_first_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(times_egdt, handle)
    
with open('monk_1/n_leaves_first_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(n_leaves_egdt, handle)
    
with open('monk_1/train_acc_first_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(train_acc_egdt, handle)
    
with open('monk_1/test_acc_first_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# ## Original

# %%
n_iter = 1000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
#lambd = 0.0025
gamma = 0.75

#lambs = [0.2, 0.1, 0.05, 0.025, 0.01, 0.005, 0.0025, 0.001, 0.0005, 0.00025, 0.0001]
lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.1397
# n_leaves =  4
# train accuracy =  0.7545045045045045
# test accuracy =  0.7142857142857143
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.0188
# n_leaves =  4
# train accuracy =  0.7348314606741573
# test accuracy =  0.7927927927927928
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.1291
# n_leaves =  4
# train accuracy =  0.7370786516853932
# test accuracy =  0.7837837837837838
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.0344
# n_leaves =  4
# train accuracy =  0.7348314606741573
# test accuracy =  0.7927927927927928
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 8.1349
# n_leaves =  4
# train accuracy =  0.7707865168539326
# test accuracy =  0.6486486486486487
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 15.7304
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.8995
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.0442
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.0060
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 14.8723
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.5860
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 15.1249
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 15.0207
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.4504
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 17.5396
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.7210
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.4601
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.3808
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 15.8963
# n_leaves =  27
# train accuracy =  1.0
# test accuracy =  1.0
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# execution time : 16.0826
# n_leaves =  28
# train accuracy =  1.0
# test accuracy =  1.0

# %%
with open('monk_1/times_original_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(times_egdt, handle)
    
with open('monk_1/n_leaves_original_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(n_leaves_egdt, handle)
    
with open('monk_1/train_acc_original_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(train_acc_egdt, handle)
    
with open('monk_1/test_acc_original_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # Monk 2

# %%
file = '../data/monk2-train.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
#np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (169, 12)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
#lambd = 0.0025
gamma = 0.75

#lambs = [0.2, 0.1, 0.05, 0.025, 0.01, 0.005, 0.0025, 0.001, 0.0005, 0.00025, 0.0001]
lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 50.6793
# n_leaves =  1
# train accuracy =  0.6222222222222222
# test accuracy =  0.6176470588235294
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 50.2577
# n_leaves =  1
# train accuracy =  0.6296296296296297
# test accuracy =  0.5882352941176471
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 49.8910
# n_leaves =  1
# train accuracy =  0.6296296296296297
# test accuracy =  0.5882352941176471
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 49.2831
# n_leaves =  1
# train accuracy =  0.6
# test accuracy =  0.7058823529411765
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 50.1986
# n_leaves =  1
# train accuracy =  0.625
# test accuracy =  0.6060606060606061
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 206.1523
# n_leaves =  16
# train accuracy =  0.8740740740740741
# test accuracy =  0.7352941176470589
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 227.4685
# n_leaves =  14
# train accuracy =  0.8814814814814815
# test accuracy =  0.7941176470588235
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 229.2792
# n_leaves =  13
# train accuracy =  0.8592592592592593
# test accuracy =  0.8235294117647058
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 230.9705
# n_leaves =  10
# train accuracy =  0.8296296296296296
# test accuracy =  0.6470588235294118
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 278.8547
# n_leaves =  12
# train accuracy =  0.8676470588235294
# test accuracy =  0.6666666666666666
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 401.8848
# n_leaves =  25
# train accuracy =  0.9407407407407408
# test accuracy =  0.7058823529411765
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 310.4954
# n_leaves =  22
# train accuracy =  0.9259259259259259
# test accuracy =  0.7647058823529411
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 307.7061
# n_leaves =  20
# train accuracy =  0.9037037037037037
# test accuracy =  0.8529411764705882
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 430.2779
# n_leaves =  31
# train accuracy =  0.9851851851851852
# test accuracy =  0.9117647058823529
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 421.9235
# n_leaves =  29
# train accuracy =  0.9705882352941176
# test accuracy =  0.8484848484848485
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 392.7944
# n_leaves =  31
# train accuracy =  0.9703703703703703
# test accuracy =  0.7058823529411765
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 421.3686
# n_leaves =  35
# train accuracy =  1.0
# test accuracy =  0.7352941176470589
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 359.2813
# n_leaves =  18
# train accuracy =  0.8888888888888888
# test accuracy =  0.7941176470588235
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 488.6589
# n_leaves =  35
# train accuracy =  0.9777777777777777
# test accuracy =  0.9117647058823529
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 435.5887
# n_leaves =  33
# train accuracy =  1.0
# test accuracy =  0.8181818181818182

# %%
with open('monk_2/times_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(times_egdt, handle)
    
with open('monk_2/n_leaves_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(n_leaves_egdt, handle)
    
with open('monk_2/train_acc_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(train_acc_egdt, handle)
    
with open('monk_2/test_acc_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # Monk 3

# %%
file = '../data/monk3-train.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
#np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (122, 12)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
#lambd = 0.0025
gamma = 0.75

#lambs = [0.2, 0.1, 0.05, 0.025, 0.01, 0.005, 0.0025, 0.001, 0.0005, 0.00025, 0.0001]
lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 89.7134
# n_leaves =  2
# train accuracy =  0.7216494845360825
# test accuracy =  0.48
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 99.8390
# n_leaves =  2
# train accuracy =  0.6701030927835051
# test accuracy =  0.68
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 118.2751
# n_leaves =  3
# train accuracy =  0.7959183673469388
# test accuracy =  0.7083333333333334
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 119.0175
# n_leaves =  3
# train accuracy =  0.7857142857142857
# test accuracy =  0.75
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 118.7960
# n_leaves =  3
# train accuracy =  0.7959183673469388
# test accuracy =  0.7083333333333334
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 223.9233
# n_leaves =  10
# train accuracy =  0.9484536082474226
# test accuracy =  0.84
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 232.6367
# n_leaves =  11
# train accuracy =  0.9484536082474226
# test accuracy =  0.96
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 245.8723
# n_leaves =  11
# train accuracy =  0.9591836734693877
# test accuracy =  0.9166666666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 236.1444
# n_leaves =  12
# train accuracy =  0.9591836734693877
# test accuracy =  0.9583333333333334
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 232.6563
# n_leaves =  11
# train accuracy =  0.9591836734693877
# test accuracy =  0.875
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 274.0286
# n_leaves =  18
# train accuracy =  1.0
# test accuracy =  0.88
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 293.1915
# n_leaves =  22
# train accuracy =  1.0
# test accuracy =  0.92
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 287.0778
# n_leaves =  19
# train accuracy =  1.0
# test accuracy =  0.9166666666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 285.0333
# n_leaves =  18
# train accuracy =  0.9795918367346939
# test accuracy =  0.8333333333333334
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 281.3087
# n_leaves =  18
# train accuracy =  1.0
# test accuracy =  0.9166666666666666
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 293.7196
# n_leaves =  20
# train accuracy =  1.0
# test accuracy =  0.84
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 272.8145
# n_leaves =  20
# train accuracy =  1.0
# test accuracy =  0.96
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 270.6490
# n_leaves =  20
# train accuracy =  1.0
# test accuracy =  0.9166666666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 289.7468
# n_leaves =  22
# train accuracy =  1.0
# test accuracy =  0.9166666666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 287.8390
# n_leaves =  18
# train accuracy =  1.0
# test accuracy =  0.9166666666666666

# %%
with open('monk_3/times_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(times_egdt, handle)
    
with open('monk_3/n_leaves_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(n_leaves_egdt, handle)
    
with open('monk_3/train_acc_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(train_acc_egdt, handle)
    
with open('monk_3/test_acc_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # Tic-Tac-Toe

# %%
file = '../data/tic-tac-toe.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (958, 19)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 20000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
#lambd = 0.0025
gamma = 0.75
#gamma = 1

#lambs = [0.2, 0.1, 0.05, 0.025, 0.01, 0.005, 0.0025, 0.001, 0.0005, 0.00025, 0.0001]
lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 115.3783
# n_leaves =  1
# train accuracy =  0.6409921671018277
# test accuracy =  0.703125
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 111.7812
# n_leaves =  1
# train accuracy =  0.6488250652741514
# test accuracy =  0.671875
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 112.4833
# n_leaves =  1
# train accuracy =  0.6488250652741514
# test accuracy =  0.671875
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 110.0250
# n_leaves =  1
# train accuracy =  0.6649282920469362
# test accuracy =  0.6073298429319371
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 109.7299
# n_leaves =  1
# train accuracy =  0.6636245110821382
# test accuracy =  0.612565445026178
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 388.5475
# n_leaves =  7
# train accuracy =  0.8107049608355091
# test accuracy =  0.8020833333333334
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 400.6433
# n_leaves =  7
# train accuracy =  0.8224543080939948
# test accuracy =  0.7604166666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 386.8927
# n_leaves =  7
# train accuracy =  0.7610966057441253
# test accuracy =  0.7760416666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 394.7780
# n_leaves =  8
# train accuracy =  0.8265971316818774
# test accuracy =  0.7539267015706806
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 379.1737
# n_leaves =  7
# train accuracy =  0.7548891786179922
# test accuracy =  0.7277486910994765
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# execution time : 600.0187
# n_leaves =  18
# train accuracy =  0.8955613577023499
# test accuracy =  0.8854166666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 495.2937
# n_leaves =  13
# train accuracy =  0.860313315926893
# test accuracy =  0.828125
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 417.2176
# n_leaves =  12
# train accuracy =  0.8537859007832899
# test accuracy =  0.8385416666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# ...
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# execution time : 600.0351
# n_leaves =  21
# train accuracy =  0.9216710182767625
# test accuracy =  0.8802083333333334
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 582.2556
# n_leaves =  17
# train accuracy =  0.8825065274151436
# test accuracy =  0.84375
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 420.5266
# n_leaves =  9
# train accuracy =  0.8211488250652742
# test accuracy =  0.7916666666666666
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 410.2945
# n_leaves =  7
# train accuracy =  0.8057366362451108
# test accuracy =  0.7853403141361257
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# iteration : 10000
# iteration : 10100
# iteration : 10200
# iteration : 10300
# iteration : 10400
# iteration : 10500
# iteration : 10600
# iteration : 10700
# iteration : 10800
# iteration : 10900
# iteration : 11000
# iteration : 11100
# iteration : 11200
# iteration : 11300
# iteration : 11400
# iteration : 11500
# iteration : 11600
# iteration : 11700
# iteration : 11800
# iteration : 11900
# iteration : 12000
# iteration : 12100
# iteration : 12200
# iteration : 12300
# iteration : 12400
# iteration : 12500
# iteration : 12600
# iteration : 12700
# iteration : 12800
# iteration : 12900
# iteration : 13000
# iteration : 13100
# iteration : 13200
# iteration : 13300
# iteration : 13400
# iteration : 13500
# iteration : 13600
# iteration : 13700
# iteration : 13800
# iteration : 13900
# iteration : 14000
# iteration : 14100
# iteration : 14200
# iteration : 14300
# iteration : 14400
# iteration : 14500
# iteration : 14600
# iteration : 14700
# iteration : 14800
# iteration : 14900
# iteration : 15000
# iteration : 15100
# iteration : 15200
# iteration : 15300
# iteration : 15400
# iteration : 15500
# iteration : 15600
# iteration : 15700
# iteration : 15800
# iteration : 15900
# iteration : 16000
# iteration : 16100
# iteration : 16200
# iteration : 16300
# iteration : 16400
# iteration : 16500
# iteration : 16600
# iteration : 16700
# iteration : 16800
# iteration : 16900
# iteration : 17000
# iteration : 17100
# iteration : 17200
# iteration : 17300
# iteration : 17400
# iteration : 17500
# iteration : 17600
# iteration : 17700
# iteration : 17800
# iteration : 17900
# iteration : 18000
# iteration : 18100
# iteration : 18200
# iteration : 18300
# iteration : 18400
# iteration : 18500
# iteration : 18600
# iteration : 18700
# iteration : 18800
# iteration : 18900
# iteration : 19000
# iteration : 19100
# iteration : 19200
# iteration : 19300
# iteration : 19400
# iteration : 19500
# iteration : 19600
# iteration : 19700
# iteration : 19800
# iteration : 19900
# execution time : 408.0677
# n_leaves =  8
# train accuracy =  0.7940026075619296
# test accuracy =  0.8010471204188482

# %%
with open('tic-tac-toe/times_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(times_egdt, handle)
    
with open('tic-tac-toe/n_leaves_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(n_leaves_egdt, handle)
    
with open('tic-tac-toe/train_acc_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(train_acc_egdt, handle)
    
with open('tic-tac-toe/test_acc_fasttsdt.pickle', 'wb') as handle:
    pkl.dump(test_acc_egdt, handle)

# %%
with open('tic-tac-toe/times_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(times_egdt, handle)
    
with open('tic-tac-toe/n_leaves_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(n_leaves_egdt, handle)
    
with open('tic-tac-toe/train_acc_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(train_acc_egdt, handle)
    
with open('tic-tac-toe/test_acc_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # Car Evaluation

# %%
file = '../data/car-evaluation.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (1728, 16)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
#lambd = 0.0025
gamma = 1

#lambs = [0.2, 0.1, 0.05, 0.025, 0.01, 0.005, 0.0025, 0.001, 0.0005, 0.00025, 0.0001]
lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 51.9603
# n_leaves =  1
# train accuracy =  0.7040520984081042
# test accuracy =  0.684971098265896
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 52.2771
# n_leaves =  1
# train accuracy =  0.695369030390738
# test accuracy =  0.7196531791907514
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 52.7395
# n_leaves =  1
# train accuracy =  0.7105643994211288
# test accuracy =  0.6589595375722543
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 52.0991
# n_leaves =  1
# train accuracy =  0.6984815618221258
# test accuracy =  0.7072463768115942
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 51.9426
# n_leaves =  1
# train accuracy =  0.6926970354302241
# test accuracy =  0.7304347826086957
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 216.9633
# n_leaves =  7
# train accuracy =  0.8979739507959479
# test accuracy =  0.8641618497109826
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 220.2485
# n_leaves =  7
# train accuracy =  0.8885672937771346
# test accuracy =  0.9017341040462428
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 175.5083
# n_leaves =  5
# train accuracy =  0.8545586107091172
# test accuracy =  0.8583815028901735
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 246.0387
# n_leaves =  9
# train accuracy =  0.9248011569052784
# test accuracy =  0.9246376811594202
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 173.5414
# n_leaves =  5
# train accuracy =  0.8582791033984093
# test accuracy =  0.8434782608695652
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 276.6009
# n_leaves =  10
# train accuracy =  0.9138929088277858
# test accuracy =  0.8757225433526011
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 474.7886
# n_leaves =  21
# train accuracy =  0.9384949348769899
# test accuracy =  0.9393063583815029
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 278.7210
# n_leaves =  12
# train accuracy =  0.947178002894356
# test accuracy =  0.9508670520231214
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 335.9341
# n_leaves =  13
# train accuracy =  0.9190166305133767
# test accuracy =  0.8898550724637682
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 261.8870
# n_leaves =  10
# train accuracy =  0.9125090383224873
# test accuracy =  0.8985507246376812
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# execution time : 600.0234
# n_leaves =  29
# train accuracy =  0.9652677279305355
# test accuracy =  0.9479768786127167
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# execution time : 600.0677
# n_leaves =  37
# train accuracy =  0.9703328509406657
# test accuracy =  0.9624277456647399
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# execution time : 600.0551
# n_leaves =  32
# train accuracy =  0.959479015918958
# test accuracy =  0.930635838150289
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# execution time : 600.1470
# n_leaves =  34
# train accuracy =  0.9501084598698482
# test accuracy =  0.927536231884058
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# execution time : 600.0233
# n_leaves =  39
# train accuracy =  0.9566160520607375
# test accuracy =  0.9246376811594202

# %%
with open('car-evaluation/times_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(times_egdt, handle)
    
with open('car-evaluation/n_leaves_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(n_leaves_egdt, handle)
    
with open('car-evaluation/train_acc_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(train_acc_egdt, handle)
    
with open('car-evaluation/test_acc_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # COMPAS

# %%
file = '../data/compas-binary.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (6907, 13)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
#lambd = 0.0025
#gamma = 0.75
gamma = 1

#lambs = [0.2, 0.1, 0.05, 0.025, 0.01, 0.005, 0.0025, 0.001, 0.0005, 0.00025, 0.0001]
lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 93.1476
# n_leaves =  2
# train accuracy =  0.6367420814479638
# test accuracy =  0.6476121562952243
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 70.3620
# n_leaves =  1
# train accuracy =  0.5409954751131222
# test accuracy =  0.5224312590448625
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 90.7701
# n_leaves =  2
# train accuracy =  0.6397032211364458
# test accuracy =  0.6357711803041275
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 79.8069
# n_leaves =  2
# train accuracy =  0.6400651465798045
# test accuracy =  0.6343229543808834
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 90.2739
# n_leaves =  2
# train accuracy =  0.6389793702497285
# test accuracy =  0.6386676321506155
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 202.1086
# n_leaves =  6
# train accuracy =  0.6526696832579185
# test accuracy =  0.6649782923299565
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 205.1943
# n_leaves =  7
# train accuracy =  0.6497737556561086
# test accuracy =  0.6490593342981187
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 205.4547
# n_leaves =  7
# train accuracy =  0.6552660152008686
# test accuracy =  0.6603910209992759
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 206.0080
# n_leaves =  5
# train accuracy =  0.6577994933043793
# test accuracy =  0.6444605358435916
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 211.9950
# n_leaves =  7
# train accuracy =  0.6549040897575099
# test accuracy =  0.6560463432295438
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 212.6152
# n_leaves =  7
# train accuracy =  0.6695022624434389
# test accuracy =  0.6664254703328509
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 212.1324
# n_leaves =  8
# train accuracy =  0.6559276018099548
# test accuracy =  0.6497829232995659
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 216.5700
# n_leaves =  7
# train accuracy =  0.6581614187477379
# test accuracy =  0.6545981173062998
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 219.4199
# n_leaves =  9
# train accuracy =  0.66576185305827
# test accuracy =  0.6538740043446778
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 222.0339
# n_leaves =  8
# train accuracy =  0.6545421643141512
# test accuracy =  0.6422881969587255
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 228.3312
# n_leaves =  9
# train accuracy =  0.663710407239819
# test accuracy =  0.6620839363241678
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 217.3513
# n_leaves =  9
# train accuracy =  0.6608144796380091
# test accuracy =  0.658465991316932
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 228.7994
# n_leaves =  8
# train accuracy =  0.6539992761491132
# test accuracy =  0.6596669080376538
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 228.8071
# n_leaves =  8
# train accuracy =  0.6702859211002533
# test accuracy =  0.6596669080376538
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 221.9323
# n_leaves =  7
# train accuracy =  0.6577994933043793
# test accuracy =  0.6480811006517017

# %%
with open('compas/times_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(times_egdt, handle)
    
with open('compas/n_leaves_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(n_leaves_egdt, handle)
    
with open('compas/train_acc_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(train_acc_egdt, handle)
    
with open('compas/test_acc_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # FICO

# %%
file = '../data/fico_binary.csv'
data = pd.DataFrame(pd.read_csv(file, sep=";")).values
np.random.shuffle(data)
labels = set(data[:, -1])
K = len(labels)
print(data.shape)
# Out:
# (10459, 18)

# %%
kf = KFold(shuffle=True, random_state=256)

# %%
n_iter = 10000
n_samples = 100
thresh_tree = -1e-6
thresh_leaf = 1e-6
thresh_mu = 0.8
thresh_sigma = 0.1
print_iter = 100
time_limit = 600
#lambd = 0.0025
#gamma = 0.75
gamma = 1

#lambs = [0.2, 0.1, 0.05, 0.025, 0.01, 0.005, 0.0025, 0.001, 0.0005, 0.00025, 0.0001]
lambs = [0.1, 0.01, 0.0025, 0.0001]
times_egdt = {}
n_leaves_egdt = {}
train_acc_egdt = {}
test_acc_egdt = {}

# %%
for lambd in lambs:
    print('lambda = ', lambd)
    times_list = []
    n_leaves_list = []
    train_acc_list = []
    test_acc_list = []
    for i, (train_index, test_index) in enumerate(kf.split(data)):
        data_train_fold = data[train_index]
        data_test_fold = data[test_index]
        stream_generator_train = StreamGeneratorReal(data_train_fold)
        stream_generator_test = StreamGeneratorReal(data_test_fold)
        tsdt = TSDT(stream_generator_train.categories, K, 'gini')
        start_time = time()
        node, searchtree = tsdt.run(stream_generator_train, n_iter, n_samples, thresh_tree, thresh_leaf, thresh_mu, thresh_sigma, 'n_visits', lambd, gamma, print_iter, time_limit)
        totaltime = time() - start_time
        print('execution time : %.4f' %totaltime)
        times_list.append(totaltime)
        nleaves_EGDT = len(node.tree.leaves)
        print('n_leaves = ', nleaves_EGDT)
        n_leaves_list.append(nleaves_EGDT)
        trainaccu_EGDT = node.test(stream_generator_train, n=stream_generator_train.data.shape[0])
        print('train accuracy = ', trainaccu_EGDT)
        train_acc_list.append(trainaccu_EGDT)
        testaccu_EGDT = node.test(stream_generator_test, n=stream_generator_test.data.shape[0])
        print('test accuracy = ', testaccu_EGDT)
        test_acc_list.append(testaccu_EGDT)
        print('\n')
        
        # Clear the memory.
        DecisionTreeNode.id_node.clear()
        DecisionTreeNode.count = 0
    
    times_egdt[lambd] = times_list
    n_leaves_egdt[lambd] = n_leaves_list
    train_acc_egdt[lambd] = train_acc_list
    test_acc_egdt[lambd] = test_acc_list
    print('\n')
# Out:
# lambda =  0.1
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 106.3812
# n_leaves =  2
# train accuracy =  0.6946336799330703
# test accuracy =  0.7012428298279159
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 102.2594
# n_leaves =  2
# train accuracy =  0.6973825743994263
# test accuracy =  0.6902485659655831
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 103.5477
# n_leaves =  2
# train accuracy =  0.6936775427273814
# test accuracy =  0.6964627151051626
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 103.7798
# n_leaves =  2
# train accuracy =  0.6964264371937373
# test accuracy =  0.6940726577437859
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 103.1329
# n_leaves =  2
# train accuracy =  0.6969407265774379
# test accuracy =  0.6920133907221425
#
#
#
#
# lambda =  0.01
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 218.6148
# n_leaves =  6
# train accuracy =  0.6916457511652923
# test accuracy =  0.7045889101338432
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 214.7309
# n_leaves =  6
# train accuracy =  0.6948727142344926
# test accuracy =  0.6916826003824091
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 217.6324
# n_leaves =  6
# train accuracy =  0.6900920282060475
# test accuracy =  0.6931166347992351
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 217.2499
# n_leaves =  6
# train accuracy =  0.6952312656866261
# test accuracy =  0.6902485659655831
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 214.8236
# n_leaves =  6
# train accuracy =  0.7135516252390057
# test accuracy =  0.7044476327116213
#
#
#
#
# lambda =  0.0025
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 233.6966
# n_leaves =  7
# train accuracy =  0.7088562208676945
# test accuracy =  0.7174952198852772
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 225.3415
# n_leaves =  7
# train accuracy =  0.6891358910003585
# test accuracy =  0.6821223709369025
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 240.6763
# n_leaves =  7
# train accuracy =  0.7041950519899606
# test accuracy =  0.7103250478011472
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 226.1986
# n_leaves =  6
# train accuracy =  0.7024022947292936
# test accuracy =  0.6988527724665392
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 232.6386
# n_leaves =  7
# train accuracy =  0.6950286806883366
# test accuracy =  0.6910569105691057
#
#
#
#
# lambda =  0.0001
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 239.5320
# n_leaves =  7
# train accuracy =  0.7061073264013386
# test accuracy =  0.7160611854684512
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 233.6902
# n_leaves =  8
# train accuracy =  0.6955898171387594
# test accuracy =  0.6888145315487572
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 234.8777
# n_leaves =  7
# train accuracy =  0.7014461575236046
# test accuracy =  0.7050669216061185
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 236.2848
# n_leaves =  7
# train accuracy =  0.7064658778534719
# test accuracy =  0.7045889101338432
#
#
# iteration : 0
# iteration : 100
# iteration : 200
# iteration : 300
# iteration : 400
# iteration : 500
# iteration : 600
# iteration : 700
# iteration : 800
# iteration : 900
# iteration : 1000
# iteration : 1100
# iteration : 1200
# iteration : 1300
# iteration : 1400
# iteration : 1500
# iteration : 1600
# iteration : 1700
# iteration : 1800
# iteration : 1900
# iteration : 2000
# iteration : 2100
# iteration : 2200
# iteration : 2300
# iteration : 2400
# iteration : 2500
# iteration : 2600
# iteration : 2700
# iteration : 2800
# iteration : 2900
# iteration : 3000
# iteration : 3100
# iteration : 3200
# iteration : 3300
# iteration : 3400
# iteration : 3500
# iteration : 3600
# iteration : 3700
# iteration : 3800
# iteration : 3900
# iteration : 4000
# iteration : 4100
# iteration : 4200
# iteration : 4300
# iteration : 4400
# iteration : 4500
# iteration : 4600
# iteration : 4700
# iteration : 4800
# iteration : 4900
# iteration : 5000
# iteration : 5100
# iteration : 5200
# iteration : 5300
# iteration : 5400
# iteration : 5500
# iteration : 5600
# iteration : 5700
# iteration : 5800
# iteration : 5900
# iteration : 6000
# iteration : 6100
# iteration : 6200
# iteration : 6300
# iteration : 6400
# iteration : 6500
# iteration : 6600
# iteration : 6700
# iteration : 6800
# iteration : 6900
# iteration : 7000
# iteration : 7100
# iteration : 7200
# iteration : 7300
# iteration : 7400
# iteration : 7500
# iteration : 7600
# iteration : 7700
# iteration : 7800
# iteration : 7900
# iteration : 8000
# iteration : 8100
# iteration : 8200
# iteration : 8300
# iteration : 8400
# iteration : 8500
# iteration : 8600
# iteration : 8700
# iteration : 8800
# iteration : 8900
# iteration : 9000
# iteration : 9100
# iteration : 9200
# iteration : 9300
# iteration : 9400
# iteration : 9500
# iteration : 9600
# iteration : 9700
# iteration : 9800
# iteration : 9900
# execution time : 240.3614
# n_leaves =  8
# train accuracy =  0.7067399617590823
# test accuracy =  0.7039693926351028

# %%
with open('fico/times_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(times_egdt, handle)
    
with open('fico/n_leaves_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(n_leaves_egdt, handle)
    
with open('fico/train_acc_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(train_acc_egdt, handle)
    
with open('fico/test_acc_fasttsdt_gamma1.pickle', 'wb') as handle:
    pkl.dump(test_acc_egdt, handle)

# %% [markdown]
# # Summary

# %%
algs = ['dl85', 'osdt', 'fasttsdt', 'tsdt']
res = ['n_leaves', 'train_acc', 'test_acc', 'times']

# %%
def construct(prob, data):
    d = {'dl85' : {}, 'osdt' : {}, 'fasttsdt' : {}, 'tsdt' : {}}

    for result in res:
        d['dl85'][result] = {}
        for depth in depths:
            d['dl85'][result][depth] = quantiles(data[result + prob + 'dl85'][depth])

        d['osdt'][result] = {}
        d['fasttsdt'][result] = {}
        d['tsdt'][result] = {}
        for lamb in lambs:
            d['osdt'][result][lamb] = quantiles(data[result + prob + 'osdt'][lamb])
            d['fasttsdt'][result][lamb] = quantiles(data[result + prob + 'fasttsdt'][lamb])
            d['tsdt'][result][lamb] = quantiles(data[result + prob + 'tsdt'][lamb])
            
    return d

# %%
legend_elements = [Line2D([0], [0], marker='o', color='b', label='dl85', markerfacecolor='b'), 
                   Line2D([0], [0], marker='s', color='g', label='osdt', markerfacecolor='g'), 
                   Line2D([0], [0], marker='v', color='r', label='fast-tsdt', markerfacecolor='r'), 
                   Line2D([0], [0], marker='^', color='y', label='tsdt', markerfacecolor='y')]

def plot_restuls(d, result, depths, lambs, ax):
    for i, depth in enumerate(depths):
        ax.plot(d['dl85']['n_leaves'][depth][1], d['dl85'][result][depth][1], marker='o', color='b')
        ax.plot([d['dl85']['n_leaves'][depth][1], d['dl85']['n_leaves'][depth][1]], 
                [d['dl85'][result][depth][0], d['dl85'][result][depth][2]], color='b')
        ax.plot([d['dl85']['n_leaves'][depth][0], d['dl85']['n_leaves'][depth][2]], 
                [d['dl85'][result][depth][1], d['dl85'][result][depth][1]], color='b')

    for i, lamb in enumerate(lambs):
        ax.plot(d['osdt']['n_leaves'][lamb][1], d['osdt'][result][lamb][1], marker='s', color='g')
        ax.plot([d['osdt']['n_leaves'][lamb][1], d['osdt']['n_leaves'][lamb][1]], 
                [d['osdt'][result][lamb][0], d['osdt'][result][lamb][2]], color='g')
        ax.plot([d['osdt']['n_leaves'][lamb][0], d['osdt']['n_leaves'][lamb][2]], 
                [d['osdt'][result][lamb][1], d['osdt'][result][lamb][1]], color='g')


        ax.plot(d['fasttsdt']['n_leaves'][lamb][1], d['fasttsdt'][result][lamb][1], marker='v', color='r')
        ax.plot([d['fasttsdt']['n_leaves'][lamb][1], d['fasttsdt']['n_leaves'][lamb][1]], 
                [d['fasttsdt'][result][lamb][0], d['fasttsdt'][result][lamb][2]], color='r')
        ax.plot([d['fasttsdt']['n_leaves'][lamb][0], d['fasttsdt']['n_leaves'][lamb][2]], 
                [d['fasttsdt'][result][lamb][1], d['fasttsdt'][result][lamb][1]], color='r')
        
        
        ax.plot(d['tsdt']['n_leaves'][lamb][1], d['tsdt'][result][lamb][1], marker='^', color='y')
        ax.plot([d['tsdt']['n_leaves'][lamb][1], d['tsdt']['n_leaves'][lamb][1]], 
                [d['tsdt'][result][lamb][0], d['tsdt'][result][lamb][2]], color='y')
        ax.plot([d['tsdt']['n_leaves'][lamb][0], d['tsdt']['n_leaves'][lamb][2]], 
                [d['tsdt'][result][lamb][1], d['tsdt'][result][lamb][1]], color='y')

# %% [markdown]
# ## Loading the results for Monk 1

# %%
monk_1 = {}
directory = 'monk_1/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    monk_1[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %% [markdown]
# ### Original

# %%
prob = '_original_'
monk_1_original_quartiles = {'fasttsdt' : {}, 'tsdt' : {}}
for result in res:
    monk_1_original_quartiles['fasttsdt'][result] = {}
    monk_1_original_quartiles['tsdt'][result] = {}
    for lamb in lambs:
        monk_1_original_quartiles['fasttsdt'][result][lamb] = quantiles(monk_1[result + prob + 'fasttsdt'][lamb])
        monk_1_original_quartiles['tsdt'][result][lamb] = quantiles(monk_1[result + prob + 'tsdt'][lamb])

# %%
result = 'test_acc'
for i, lamb in enumerate(lambs):
    plt.plot(monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt'][result][lamb][1], marker='v', color='r')
    plt.plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['fasttsdt'][result][lamb][0], monk_1_original_quartiles['fasttsdt'][result][lamb][2]], color='r')
    plt.plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['fasttsdt'][result][lamb][1], monk_1_original_quartiles['fasttsdt'][result][lamb][1]], color='r')
    
    plt.plot(monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt'][result][lamb][1], marker='^', color='y')
    plt.plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['tsdt'][result][lamb][0], monk_1_original_quartiles['tsdt'][result][lamb][2]], color='y')
    plt.plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['tsdt'][result][lamb][1], monk_1_original_quartiles['tsdt'][result][lamb][1]], color='y')
        
plt.show()

# %% [markdown]
# ### Drop Last

# %%
prob = '_last_'
monk_1_last_quartiles = construct(prob, monk_1)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(monk_1_last_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(monk_1_last_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(monk_1_last_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Drop First

# %%
prob = '_first_'
monk_1_first_quartiles = construct(prob, monk_1)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(monk_1_first_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(monk_1_first_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(monk_1_first_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for Monk 2

# %%
monk_2 = {}
directory = 'monk_2/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    monk_2[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
monk_2_quartiles = construct(prob, monk_2)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(monk_2_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(monk_2_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(monk_2_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for Monk 3

# %%
monk_3 = {}
directory = 'monk_3/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    monk_3[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
monk_3_quartiles = construct(prob, monk_3)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(monk_3_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(monk_3_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(monk_3_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for Tic-Tac-Toe

# %%
tic_tac_toe = {}
directory = 'tic-tac-toe/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    tic_tac_toe[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
tic_tac_toe_quartiles = construct(prob, tic_tac_toe)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(tic_tac_toe_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(tic_tac_toe_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(tic_tac_toe_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for Car-Evaluation

# %%
car = {}
directory = 'car-evaluation/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    car[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
car_quartiles = construct(prob, car)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(car_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(car_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(car_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for COMPAS

# %%
compas = {}
directory = 'compas/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    compas[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
compas_quartiles = construct(prob, compas)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(compas_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(compas_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(compas_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the results for FICO

# %%
fico = {}
directory = 'fico/'
for file_name_full in os.listdir(directory):
    with open(directory + file_name_full, 'rb') as file:
        result = pkl.load(file)
        
    file_name = file_name_full.split('.')[0]
    fico[file_name] = result

# %%
depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

# %%
prob = '_'
fico_quartiles = construct(prob, fico)

# %%
fig, axs = plt.subplots(1, 3, figsize = (16, 4))
plot_restuls(fico_quartiles, 'train_acc', depths, lambs, axs[0])
plot_restuls(fico_quartiles, 'test_acc', depths, lambs, axs[1])
plot_restuls(fico_quartiles, 'times', depths, lambs, axs[2])

plt.legend(handles=legend_elements)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Concluding Figures

# %%
fig, axs = plt.subplots(3, 3, figsize=(26, 16))

prob = 'train_acc'

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_1_last_quartiles, prob, depths, lambs, axs[0, 0])
axs[0, 0].set_title('MONK1 Drop last', fontsize=30)
axs[0, 0].set_ylabel('Training Accuracy', fontsize=24)
axs[0, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_1_first_quartiles, prob, depths, lambs, axs[0, 1])
axs[0, 1].set_title('MONK1 Drop first', fontsize=30)
axs[0, 1].tick_params(axis='both', labelsize=20)

for i, lamb in enumerate(lambs):
    axs[0, 2].plot(monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1], marker='v', color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][0], monk_1_original_quartiles['fasttsdt'][prob][lamb][2]], color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1]], color='r')
    
    axs[0, 2].plot(monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1], marker='^', color='y')
    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['tsdt'][prob][lamb][0], monk_1_original_quartiles['tsdt'][prob][lamb][2]], color='y')
    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['tsdt'][prob][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1]], color='y')
    
axs[0, 2].set_title('MONK1 Original', fontsize=30)
axs[0, 2].tick_params(axis='both', labelsize=20)

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_2_quartiles, prob, depths, lambs, axs[1, 0])
axs[1, 0].set_title('MONK2', fontsize=30)
axs[1, 0].set_ylabel('Training Accuracy', fontsize=24)
axs[1, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_3_quartiles, prob, depths, lambs, axs[1, 1])
axs[1, 1].set_title('MONK3', fontsize=30)
axs[1, 1].tick_params(axis='both', labelsize=20)

plot_restuls(tic_tac_toe_quartiles, prob, depths, lambs, axs[1, 2])
axs[1, 2].set_title('Tic-Tac-Toe', fontsize=30)
axs[1, 2].tick_params(axis='both', labelsize=20)

plot_restuls(car_quartiles, prob, depths, lambs, axs[2, 0])
axs[2, 0].set_title('Car-Evaluation', fontsize=30)
axs[2, 0].set_ylabel('Training Accuracy', fontsize=24)
axs[2, 0].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 0].tick_params(axis='both', labelsize=20)

plot_restuls(compas_quartiles, prob, depths, lambs, axs[2, 1])
axs[2, 1].set_title('COMPAS', fontsize=30)
axs[2, 1].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 1].tick_params(axis='both', labelsize=20)

plot_restuls(fico_quartiles, prob, depths, lambs, axs[2, 2])
axs[2, 2].set_title('FICO', fontsize=30)
axs[2, 2].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 2].tick_params(axis='both', labelsize=20)

plt.legend(handles=legend_elements, loc='lower right', fontsize=20)
plt.tight_layout()
plt.savefig('train_accuracies.png')
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(26, 16))

prob = 'test_acc'

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_1_last_quartiles, prob, depths, lambs, axs[0, 0])
axs[0, 0].set_title('MONK1 Drop last', fontsize=30)
axs[0, 0].set_ylabel('Test Accuracy', fontsize=24)
axs[0, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_1_first_quartiles, prob, depths, lambs, axs[0, 1])
axs[0, 1].set_title('MONK1 Drop first', fontsize=30)
axs[0, 1].tick_params(axis='both', labelsize=20)

for i, lamb in enumerate(lambs):
    axs[0, 2].plot(monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1], marker='v', color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][0], monk_1_original_quartiles['fasttsdt'][prob][lamb][2]], color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1]], color='r')
    
    axs[0, 2].plot(monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1], marker='^', color='y')
    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['tsdt'][prob][lamb][0], monk_1_original_quartiles['tsdt'][prob][lamb][2]], color='y')
    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['tsdt'][prob][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1]], color='y')
    
axs[0, 2].set_title('MONK1 Original', fontsize=30)
axs[0, 2].tick_params(axis='both', labelsize=20)

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_2_quartiles, prob, depths, lambs, axs[1, 0])
axs[1, 0].set_title('MONK2', fontsize=30)
axs[1, 0].set_ylabel('Test Accuracy', fontsize=24)
axs[1, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_3_quartiles, prob, depths, lambs, axs[1, 1])
axs[1, 1].set_title('MONK3', fontsize=30)
axs[1, 1].tick_params(axis='both', labelsize=20)

plot_restuls(tic_tac_toe_quartiles, prob, depths, lambs, axs[1, 2])
axs[1, 2].set_title('Tic-Tac-Toe', fontsize=30)
axs[1, 2].tick_params(axis='both', labelsize=20)

plot_restuls(car_quartiles, prob, depths, lambs, axs[2, 0])
axs[2, 0].set_title('Car-Evaluation', fontsize=30)
axs[2, 0].set_ylabel('Test Accuracy', fontsize=24)
axs[2, 0].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 0].tick_params(axis='both', labelsize=20)

plot_restuls(compas_quartiles, prob, depths, lambs, axs[2, 1])
axs[2, 1].set_title('COMPAS', fontsize=30)
axs[2, 1].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 1].tick_params(axis='both', labelsize=20)

plot_restuls(fico_quartiles, prob, depths, lambs, axs[2, 2])
axs[2, 2].set_title('FICO', fontsize=30)
axs[2, 2].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 2].tick_params(axis='both', labelsize=20)

plt.legend(handles=legend_elements, loc='lower right', fontsize=20)
plt.tight_layout()
plt.savefig('test_accuracies.png')
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(26, 16))

prob = 'times'

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_1_last_quartiles, prob, depths, lambs, axs[0, 0])
axs[0, 0].set_title('MONK1 Drop last', fontsize=30)
axs[0, 0].set_ylabel('Time (s)', fontsize=24)
axs[0, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_1_first_quartiles, prob, depths, lambs, axs[0, 1])
axs[0, 1].set_title('MONK1 Drop first', fontsize=30)
axs[0, 1].tick_params(axis='both', labelsize=20)

for i, lamb in enumerate(lambs):
    axs[0, 2].plot(monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1], marker='v', color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][0], monk_1_original_quartiles['fasttsdt'][prob][lamb][2]], color='r')
    axs[0, 2].plot([monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['fasttsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['fasttsdt'][prob][lamb][1], monk_1_original_quartiles['fasttsdt'][prob][lamb][1]], color='r')
    
    axs[0, 2].plot(monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1], marker='^', color='y')
    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][1]], 
            [monk_1_original_quartiles['tsdt'][prob][lamb][0], monk_1_original_quartiles['tsdt'][prob][lamb][2]], color='y')
    axs[0, 2].plot([monk_1_original_quartiles['tsdt']['n_leaves'][lamb][0], monk_1_original_quartiles['tsdt']['n_leaves'][lamb][2]], 
            [monk_1_original_quartiles['tsdt'][prob][lamb][1], monk_1_original_quartiles['tsdt'][prob][lamb][1]], color='y')
    
axs[0, 2].set_title('MONK1 Original', fontsize=30)
axs[0, 2].tick_params(axis='both', labelsize=20)

depths = range(1, 7)
lambs = [0.1, 0.01, 0.0025, 0.0001]

plot_restuls(monk_2_quartiles, prob, depths, lambs, axs[1, 0])
axs[1, 0].set_title('MONK2', fontsize=30)
axs[1, 0].set_ylabel('Time (s)', fontsize=24)
axs[1, 0].tick_params(axis='both', labelsize=20)

plot_restuls(monk_3_quartiles, prob, depths, lambs, axs[1, 1])
axs[1, 1].set_title('MONK3', fontsize=30)
axs[1, 1].tick_params(axis='both', labelsize=20)

plot_restuls(tic_tac_toe_quartiles, prob, depths, lambs, axs[1, 2])
axs[1, 2].set_title('Tic-Tac-Toe', fontsize=30)
axs[1, 2].tick_params(axis='both', labelsize=20)

plot_restuls(car_quartiles, prob, depths, lambs, axs[2, 0])
axs[2, 0].set_title('Car-Evaluation', fontsize=30)
axs[2, 0].set_ylabel('Time (s)', fontsize=24)
axs[2, 0].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 0].tick_params(axis='both', labelsize=20)

plot_restuls(compas_quartiles, prob, depths, lambs, axs[2, 1])
axs[2, 1].set_title('COMPAS', fontsize=30)
axs[2, 1].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 1].tick_params(axis='both', labelsize=20)

plot_restuls(fico_quartiles, prob, depths, lambs, axs[2, 2])
axs[2, 2].set_title('FICO', fontsize=30)
axs[2, 2].set_xlabel('Number of Leaves', fontsize=24)
axs[2, 2].tick_params(axis='both', labelsize=20)

plt.legend(handles=legend_elements, loc='lower right', fontsize=20)
plt.tight_layout()
plt.savefig('times.png')
plt.show()
